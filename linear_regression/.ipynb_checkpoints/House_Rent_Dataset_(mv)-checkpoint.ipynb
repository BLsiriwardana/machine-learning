# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Book2.csv") #import data set from csv file via using "pandas"

# %%
data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
BHK = np.array(data.BHK.values)
#Size = np.array(data.Size.values)
Rent = np.array(data.Rent.values)

# %%
#x = np.column_stack((BHK, Size))

# %%
x_train,x_test,y_train,y_test = train_test_split(BHK,Rent)

# %%
model = LinearRegression()
model.fit(x_train.reshape((-1,1)),y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(BHK,Rent,color='red') #give data set for x & y axis 
plt.xlabel('BHK') # named axis 
plt.ylabel('Rent Price')
m,c = np.polyfit(BHK,Rent,1)
plt.plot(x,m*x+c)

# %%
model.predict([[45,180,3100]])
# Out:
# C:\Users\bihan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41483.5043287])

# %%
m1,m2,m3 = model.coef_

# %%
c = model.intercept_

# %%
y = m1*45+ m2*180 +m3*3100 + c

# %%
y
# Out:
# np.float64(41483.504328703)
